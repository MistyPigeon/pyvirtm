# %%
print("pyvirtm v0.0.1 ALPHA")
print("Copyright (c) 2025 MistyPigeon. All rights reserved.")
print("Enter password to continue:")
password = input("If you dont have a password or want to replace it add any text with numbers and/or letters in the line after this after ==")
if password == "v001":
    print("Welcome to the system!")
    cmd = input("Enter command: ")
if cmd == "run notebook":
        print("Running notebook...")
        # %run ./example.ipynb
elif cmd == "exit":
        print("Shutting down pyvirtm...")
